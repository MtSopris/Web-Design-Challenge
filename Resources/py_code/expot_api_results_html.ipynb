# %%
import pandas as pd

# %%
# File to Load (Remember to Change These)
file_to_load = "cities2.csv"

# Read Purchasing File and store into Pandas data frame
cities_df = pd.read_csv(file_to_load)
cities_df
# Out:
#                       City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0                 Kalmunai   7.42   81.82     78.40        85          36
# 1                  Rikitea -23.12 -134.97     80.46        70          38
# 2              Santa Maria -29.68  -53.81     75.20        83           0
# 3                  Butembo   0.15   29.28     59.54        69          12
# 4                 Cidreira -30.18  -50.21     75.16        89          39
# ..                     ...    ...     ...       ...       ...         ...
# 543               Udimskiy  61.14   45.91     17.91        97         100
# 544  Itacurubí del Rosario -24.50  -56.68     73.85        96          53
# 545        Charters Towers -20.10  146.27     88.97        31          76
# 546            Três Lagoas -20.75  -51.68     71.87        92          84
# 547            Antofagasta -23.65  -70.40     66.20        77           0
#
#      Wind Speed Country        Date
# 0          8.57      LK  1611975828
# ...

# %%
cities_df.to_html ('table.html', index=False, classes=['table-stripped'])

# %%
my_list = cities_df.columns.values.tolist()
my_list
# Out:
# ['City',
#  'Lat',
#  'Lng',
#  'Max Temp',
#  'Humidity',
#  'Cloudiness',
#  'Wind Speed',
#  'Country',
#  'Date']
